# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 7 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035,
'le-wagon' : 10868,
'general-assembly' : 10761,
'shecodes' : 11014,
'Wild-code-school' : 11169
}

import re
import pandas as pd
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])

    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['rawbody'] = reviews['body'].apply(remove_tags)
    reviews['body'] = reviews['body'].apply(remove_tags)
    reviews['comments'] = reviews['body'].apply(remove_tags)
    reviews['user'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard
# le-wagon
# general-assembly
# shecodes
# Wild-code-school

# %%
comments_df = pd.DataFrame(comments)

# %%
comments_df = comments_df.drop(columns=["rawBody"])

# %%
comments_df
# Out:
#         id        name  anonymous       hostProgramName  graduatingYear  \
# 0   302783   Anonymous       True                  None          2023.0
# 1   302774   Anonymous       True                  None          2023.0
# 2   302682   Anonymous       True                  None          2023.0
# 3   302245        Anna      False                  None          2023.0
# 4   301920  Pedro Dias      False                  None          2023.0
# ..     ...         ...        ...                   ...             ...
# 95  247296       Sarah      False  Software Engineering          2019.0
# 96  247259     Anelisy      False  Software Engineering          2019.0
# 97  247250  Anastasiya      False  Software Engineering          2019.0
# 98  245276          DK      False  Software Engineering          2019.0
# 99  245211     Camille      False  Software Engineering          2019.0
#
#    isAlumni             jobTitle  \
# 0     False  Tracking specialist
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...                  ...
# 95     True                 None
# 96     True                 None
# 97     True                 None
# 98     True                 None
# 99     True                 None
#
#                                               tagline  \
# 0                                    Overall positive
# 1                                            Awesome!
# 2   The bootcamp in general is good, but not worth...
# 3   The Bootcamp experience was very mixed and the...
# 4   Updated content, great teacher, exciting proje...
# ..                                                ...
# 95                            Wild Code School Berlin
# 96                    Amazing support - Lisbon Campus
# 97                   Wild Code School - Berlin Campus
# 98                     Wild Code School Berlin campus
# 99                                     Berlin Campus
#
#                                                  body  createdAt  ...  \
# 0   Ironhack was a very good experience for me. I'...  7/11/2023  ...
# 1   My skill level has been enhanced, I met people...  7/11/2023  ...
# 2   For the value of 8 thousand euros I expected m...   7/7/2023  ...
# 3   Pros: Group work and individual projects Basic...  6/22/2023  ...
# 4   I had some experience coding as a hobby and ha...  6/10/2023  ...
# ..                                                ...        ...  ...
# 95  Wild Code School Berlin is empowering, relevan...  3/15/2019  ...
# 96  The application is pretty straight forward, wi...  3/13/2019  ...
# 97  I'm totally satisfied with the approach Wild C...  3/12/2019  ...
# 98  I visited Berlin campus on opening meetup and ...  3/12/2019  ...
# 99  I've just successfully passed the application ...  3/12/2019  ...
#
#                      program  \
# 0   Web Development Bootcamp
# 1                       None
# 2      UX/UI Design Bootcamp
# 3      UX/UI Design Bootcamp
# 4   Web Development Bootcamp
# ..                       ...
# 95          Web development
# 96          Web development
# 97          Web development
# 98          Web development
# 99          Web development
#
#                                                  user overallScore  \
# 0   Ironhack was a very good experience for me. I'...          4.7
# 1   My skill level has been enhanced, I met people...          5.0
# 2   For the value of 8 thousand euros I expected m...          2.7
# 3   Pros: Group work and individual projects Basic...          2.0
# 4   I had some experience coding as a hobby and ha...          4.7
# ..                                                ...          ...
# 95  Wild Code School Berlin is empowering, relevan...          5.0
# 96  The application is pretty straight forward, wi...          5.0
# 97  I'm totally satisfied with the approach Wild C...          5.0
# 98  I visited Berlin campus on opening meetup and ...          5.0
# 99  I've just successfully passed the application ...          5.0
#
#                                              comments overall curriculum  \
# 0   Ironhack was a very good experience for me. I'...     5.0        5.0
# 1   My skill level has been enhanced, I met people...     5.0        5.0
# 2   For the value of 8 thousand euros I expected m...     3.0        2.0
# 3   Pros: Group work and individual projects Basic...     2.0        2.0
# 4   I had some experience coding as a hobby and ha...     5.0        5.0
# ..                                                ...     ...        ...
# 95  Wild Code School Berlin is empowering, relevan...     5.0        5.0
# 96  The application is pretty straight forward, wi...     5.0        5.0
# 97  I'm totally satisfied with the approach Wild C...     5.0        5.0
# 98  I visited Berlin campus on opening meetup and ...     5.0        5.0
# 99  I've just successfully passed the application ...     5.0        5.0
#
#    jobSupport                                        review_body  \
# 0         4.0  Ironhack was a very good experience for me. I'...
# 1         5.0  My skill level has been enhanced, I met people...
# 2         3.0  For the value of 8 thousand euros I expected m...
# 3         2.0  Pros: Group work and individual projects Basic...
# 4         4.0  I had some experience coding as a hobby and ha...
# ..        ...                                                ...
# 95        NaN  Wild Code School Berlin is empowering, relevan...
# 96        5.0  The application is pretty straight forward, wi...
# 97        NaN  I'm totally satisfied with the approach Wild C...
# 98        NaN  I visited Berlin campus on opening meetup and ...
# 99        NaN  I've just successfully passed the application ...
#
#                                               rawbody            school
# 0   Ironhack was a very good experience for me. I'...          ironhack
# 1   My skill level has been enhanced, I met people...          ironhack
# 2   For the value of 8 thousand euros I expected m...          ironhack
# 3   Pros: Group work and individual projects Basic...          ironhack
# 4   I had some experience coding as a hobby and ha...          ironhack
# ..                                                ...               ...
# 95  Wild Code School Berlin is empowering, relevan...  Wild-code-school
# 96  The application is pretty straight forward, wi...  Wild-code-school
# 97  I'm totally satisfied with the approach Wild C...  Wild-code-school
# 98  I visited Berlin campus on opening meetup and ...  Wild-code-school
# 99  I've just successfully passed the application ...  Wild-code-school
#
# [9128 rows x 21 columns]

# %%
import pandas as pd

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = pd.json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])

    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school


    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# app-academy
# springboard
# le-wagon
# general-assembly
# shecodes
# Wild-code-school

# %%
locations_list[0]
# Out:
#       id               description  country.id   country.name country.abbrev  \
# 0  15901           Berlin, Germany        57.0        Germany             DE
# 1  16022       Mexico City, Mexico        29.0         Mexico             MX
# 2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
# 3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
# 4  16109             Paris, France        38.0         France             FR
# 5  16375  Miami, FL, United States         1.0  United States             US
# 6  16376             Madrid, Spain        12.0          Spain             ES
# 7  16377          Barcelona, Spain        12.0          Spain             ES
# 8  16709          Lisbon, Portugal        28.0       Portugal             PT
# 9  17233                    Online         NaN            NaN            NaN
#
#    city.id    city.name city.keyword  state.id state.name state.abbrev  \
# 0  31156.0       Berlin       berlin       NaN        NaN          NaN
# 1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
# 2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
# 3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
# 4  31136.0        Paris        paris       NaN        NaN          NaN
# 5     31.0        Miami        miami      11.0    Florida           FL
# 6  31052.0       Madrid       madrid       NaN        NaN          NaN
# 7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
# 8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
# 9      NaN          NaN          NaN       1.0     Online       Online
#
#   state.keyword    school  school_id
# 0           NaN  ironhack      10828
# 1           NaN  ironhack      10828
# 2           NaN  ironhack      10828
# 3           NaN  ironhack      10828
# 4           NaN  ironhack      10828
# 5       florida  ironhack      10828
# 6           NaN  ironhack      10828
# 7           NaN  ironhack      10828
# 8           NaN  ironhack      10828
# 9        online  ironhack      10828

# %%
locations = pd.concat(locations_list)
locations
# Out:
#        id             description  country.id country.name country.abbrev  \
# 0   15901         Berlin, Germany        57.0      Germany             DE
# 1   16022     Mexico City, Mexico        29.0       Mexico             MX
# 2   16086  Amsterdam, Netherlands        59.0  Netherlands             NL
# 3   16088       Sao Paulo, Brazil        42.0       Brazil             BR
# 4   16109           Paris, France        38.0       France             FR
# ..    ...                     ...         ...          ...            ...
# 21  17145            Milan, Italy        39.0        Italy             IT
# 22  17146  Amsterdam, Netherlands        59.0  Netherlands             NL
# 23  17147        Barcelona, Spain        12.0        Spain             ES
# 24  17472                  Online         NaN          NaN            NaN
# 25  17473      Bruxelles, Belgium        46.0      Belgium             BE
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
# 0   31156.0       Berlin       berlin       NaN        NaN          NaN
# 1   31175.0  Mexico City  mexico-city       NaN        NaN          NaN
# 2   31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
# 3   31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
# 4   31136.0        Paris        paris       NaN        NaN          NaN
# ..      ...          ...          ...       ...        ...          ...
# 21  31107.0        Milan        milan       NaN        NaN          NaN
# 22  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
# 23  31170.0    Barcelona    barcelona       NaN        NaN          NaN
# 24      NaN          NaN          NaN       1.0     Online       Online
# 25  31241.0    Bruxelles    bruxelles       NaN        NaN          NaN
#
#    state.keyword            school  school_id
# 0            NaN          ironhack      10828
# 1            NaN          ironhack      10828
# 2            NaN          ironhack      10828
# 3            NaN          ironhack      10828
# 4            NaN          ironhack      10828
# ..           ...               ...        ...
# 21           NaN  Wild-code-school      11169
# 22           NaN  Wild-code-school      11169
# 23           NaN  Wild-code-school      11169
# 24        online  Wild-code-school      11169
# 25           NaN  Wild-code-school      11169
#
# [84 rows x 14 columns]

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                                 courses       school  school_id
# 0               Cyber Security Bootcamp     ironhack      10828
# 1               Cybersecurity Part-Time     ironhack      10828
# 2               Data Analytics Bootcamp     ironhack      10828
# 3              Data Analytics Part-Time     ironhack      10828
# 4                 UX/UI Design Bootcamp     ironhack      10828
# 5                UX/UI Design Part-Time     ironhack      10828
# 6              Web Development Bootcamp     ironhack      10828
# 7             Web Development Part-Time     ironhack      10828
# 0  16-week Software Engineering Program  app-academy      10525
# 1                         Bootcamp Prep  app-academy      10525

# %%
courses
# Out:
#                                               courses            school  \
# 0                             Cyber Security Bootcamp          ironhack
# 1                             Cybersecurity Part-Time          ironhack
# 2                             Data Analytics Bootcamp          ironhack
# 3                            Data Analytics Part-Time          ironhack
# 4                               UX/UI Design Bootcamp          ironhack
# 5                              UX/UI Design Part-Time          ironhack
# 6                            Web Development Bootcamp          ironhack
# 7                           Web Development Part-Time          ironhack
# 0                16-week Software Engineering Program       app-academy
# 1                                       Bootcamp Prep       app-academy
# 2    24-week Software Engineering Program (Full Time)       app-academy
# 3    48-week Software Engineering Program (Part Time)       app-academy
# 4                                    App Academy Open       app-academy
# 5                     Self-Paced Bootcamp Prep Online       app-academy
# 0                         Cyber Security Career Track       springboard
# 1                         Data Analytics Career Track       springboard
# 2                           Data Science Career Track       springboard
# 3                      Data Science Career Track Prep       springboard
# 4                           Front-End Web Development       springboard
# 5                      Introduction to Data Analytics       springboard
# 6                              Introduction to Design       springboard
# 7                   Software Engineering Career Track       springboard
# 8       Software Engineering Career Track Prep Course       springboard
# 9            Software Engineering Foundations to Core       springboard
# 10                            Tech Sales Career Track       springboard
# 11                          UI/UX Design Career Track       springboard
# 12                                    UX Career Track       springboard
# 0                          Data Analytics - Full-Time          le-wagon
# 1                          Data Analytics - Part-Time          le-wagon
# 2                        Data Engineering - Full-Time          le-wagon
# 3                        Data Engineering - Part-Time          le-wagon
# 4                            Data Science - Full-Time          le-wagon
# 5                            Data Science - Part-Time          le-wagon
# 6                         Web Development - Full-Time          le-wagon
# 7                         Web Development - Part-Time          le-wagon
# 0                          Data Analytics (Part-Time)  general-assembly
# 1                            Data Analytics Immersive  general-assembly
# 2                            Data Science (Part-Time)  general-assembly
# 3                              Data Science Immersive  general-assembly
# 4                       Digital Marketing (Part-Time)  general-assembly
# 5               Front-End Web Development (Part-Time)  general-assembly
# 6                              JavaScript Development  general-assembly
# 7                      Product Management (Part-Time)  general-assembly
# 8                      Python Programming (Part-Time)  general-assembly
# 9                       React Development (Part-Time)  general-assembly
# 10                     Software Engineering Immersive  general-assembly
# 11                 User Experience Design (Part-Time)  general-assembly
# 12                   User Experience Design Immersive  general-assembly
# 13                          Visual Design (Part-Time)  general-assembly
# 0                                     SheCodes Basics          shecodes
# 1                                        SheCodes Max          shecodes
# 2                                       SheCodes Plus          shecodes
# 3                                        SheCodes Pro          shecodes
# 0                     Full-time Cybersecurity Analyst  Wild-code-school
# 1                              Full-time Data Analyst  Wild-code-school
# 2                             Full-time Web Developer  Wild-code-school
# 3                   Work-Study Advanced Web Developer  Wild-code-school
# 4                   Part-time Front-End Web Developer  Wild-code-school
# 5   Part-time Business Intelligence and Data Visua...  Wild-code-school
#
#     school_id
# 0       10828
# 1       10828
# 2       10828
# 3       10828
# 4       10828
# 5       10828
# 6       10828
# 7       10828
# 0       10525
# 1       10525
# 2       10525
# 3       10525
# 4       10525
# 5       10525
# 0       11035
# 1       11035
# 2       11035
# 3       11035
# 4       11035
# 5       11035
# 6       11035
# 7       11035
# 8       11035
# 9       11035
# 10      11035
# 11      11035
# 12      11035
# 0       10868
# 1       10868
# 2       10868
# 3       10868
# 4       10868
# 5       10868
# 6       10868
# 7       10868
# 0       10761
# 1       10761
# 2       10761
# 3       10761
# 4       10761
# 5       10761
# 6       10761
# 7       10761
# 8       10761
# 9       10761
# 10      10761
# 11      10761
# 12      10761
# 13      10761
# 0       11014
# 1       11014
# 2       11014
# 3       11014
# 0       11169
# 1       11169
# 2       11169
# 3       11169
# 4       11169
# 5       11169

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525

# %%
# any data cleaning still missing here? take a look at the description
import pandas as pd
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0                                    www.lewagon.com
# 0  generalassemb.ly?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>Le Wagon is a glo...
# 0  <span class="truncatable"><p>General Assembly ...
#
#                                              LogoUrl            school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...       app-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...       springboard
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          le-wagon
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  general-assembly
#
#    school_id
# 0      10828
# 0      10525
# 0      11035
# 0      10868
# 0      10761

# %%
import re
import pandas as pd
import requests
comments = []
locations_list = []
courses_list = []
badges_list = []
schools_list = []

def get_data_comments():
    for school in schools.keys():
        print(school)
        comments.append(get_comments_school(school))
    for school, id in schools.items():
        print(school)
        a,b,c,d = get_school_info(school,id)

        locations_list.append(a)
        courses_list.append(b)
        badges_list.append(c)
        schools_list.append(d)
    locations = pd.concat(locations_list)
    comments = pd.concat(comments)
    schools = pd.concat(schools_list)
    badges = pd.concat(badges_list)
    return "Data adquiried"

# %%
import mysql.connector
def connect_to_base():
    cnx = mysql.connector.connect(user='root',
                                password='547812',
                                host='localhost',
                                database='sakila')

# %%
def drop_database():
    query = ('''DROP DATABASE IF EXISTS project; ''')
    cursor = cnx.cursor()
    cursor.execute(query)

# %%
def create_database(project):
    query = (f'''CREATE DATABASE IF NOT EXISTS {project}; ''')
    cursor = cnx.cursor()
    cursor.execute(query)
    return "done"

# %%
def use_database(database):
    query = (f'''USE {database}; ''')
    cursor = cnx.cursor()
    cursor.execute(query)
    return "done"

# %%
drop_database()
create_database()
use_database("project")
# Out:
# 'done'

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw='547812',
                               db="project"))

# %%
courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()

# %%
badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()

# %%
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()

# %%
schools.to_sql('schools', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()

# %%
def add_data():
        schools.to_sql('schools', con = engine, if_exists = 'append', chunksize = 2000)
    cnx.commit()
        courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 2000)
    cnx.commit()
        badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()
        locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()
        schools.to_sql('schools', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()
    return "All added"

# %%
comments_df.to_sql('comments', con = engine, if_exists = 'append', chunksize = 2000)
cnx.commit()

# %%
def remove_table(table,column):
    query = (f'''ALTER TABLE {table} DROP {column} ;''')
    cursor = cnx.cursor()
    cursor.execute(query)
    cnx.commit()
    return "Done"

# %%
remove_table("comments","rawBody")
remove_table("comments","review_Body")
remove_table("comments","user")
remove_table("comments","Body")
remove_table("comments","createdat")
remove_table("comments","anonymous")
'''remove_table("comments","id"-> used by primary and ref.'''
# Out:
# 'remove_table("comments","id")'

# %%
def define_PK(table,column):
    query = (f'''ALTER TABLE {table} ADD PRIMARY KEY ({column}) ;''')
    cursor = cnx.cursor()
    cursor.execute(query)
    cnx.commit()
    return "Done"
def define_FK(table,column,table2,column_og):
    query = (f'''ALTER TABLE {table} ADD FOREIGN KEY ({column}) REFERENCES {table2}({column_og}) ;''')
    cursor = cnx.cursor()
    cursor.execute(query)
    cnx.commit()
    return "Done"

# %%
define_PK("schools","school_id")
# Out:
# 'Done'

# %%
define_PK("comments","id")
# Out:
# 'Done'

# %%
#define_FK("comments","program","courses","school") -> Couldn't make it work properly

# %% [markdown]
# The Update function, lacked focus on wich data are really necessary, kinda of missed the point on what to export.

# %%
import mysql.connector
import pymysql
from sqlalchemy import create_engine
import re
import pandas as pd
import requests
schools = {
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035,
'le-wagon' : 10868,
'general-assembly' : 10761,
'shecodes' : 11014,
'Wild-code-school' : 11169
}

def connect_to_base(database):
    cnx = mysql.connector.connect(user='root',
                                password='547812',
                                host='localhost',
                                database=f'{database}')
    engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw='547812',
                               db=f'{database}'))
    query = (f'''USE {database}; ''')
    cursor = cnx.cursor()
    cursor.execute(query)
    return "done"

def add_data():
    comments_df.to_sql('comments', con = engine, if_exists = 'append', chunksize = 2000)
    cnx.commit()
    return "All added"
comments = []
locations_list = []
courses_list = []
badges_list = []
schools_list = []

def get_data_comments():
    for school in schools.keys():
        print(school)
        comments.append(get_comments_school(school))
    for school, id in schools.items():
        print(school)
        a,b,c,d = get_school_info(school,id)

        locations_list.append(a)
        courses_list.append(b)
        badges_list.append(c)
        schools_list.append(d)
    locations = pd.concat(locations_list)
    comments = pd.concat(comments)
    schools = pd.concat(schools_list)
    badges = pd.concat(badges_list)
    return "Data adquiried"
def update(database):
    get_data_comments()
    connect_to_base(f"{database}")
    create_database(f"{database}")
    use_database(f"{database}")
    add_data()

# %%
update("project")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 update("project")
#
# Cell In[62], line 59, in update(database)
#      58 def update(database):
# ---> 59     get_data_comments()
#      60     connect_to_base(f"{database}")
#      61     create_database(f"{database}")
#
# Cell In[62], line 42, in get_data_comments()
#      41 def get_data_comments():
# ---> 42     for school in schools.keys():
#      43         print(school)
#      44         comments.append(get_comments_school(school))
#
# UnboundLocalError: cannot access local variable 'schools' where it is not associated with a value
